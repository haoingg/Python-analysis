# %%
stname = "유니코"; stage=20; stavg=95.869
print(stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다")
print(stname, "학생은 나이가 ", stage, "이고 평균은 ", stavg, "입니다", sep="")
print("%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stag e, stavg))
print("{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg))
print(f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다")
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
v1 = stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다"
v2 = "%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg)
v3 = "{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg)
v4 = f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다"
print(v1)
print(v2)
print(v3)
print(v4)
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
import sys
print(sys.version)
# Out:
# 3.8.8 (default, Feb 24 2021, 15:54:32) [MSC v.1928 64 bit (AMD64)]

# %%
import os
print(os.getcwd())
# Out:
# C:\KHY\PYDATAexam\3월24일

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   pydatavenv    C:\Users\haoin\AppData\Roaming\jupyter\kernels\pydatavenv
#   python3       C:\Users\haoin\anaconda3\share\jupyter\kernels\python3

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 1643-73CF
#
#  C:\KHY\PYDATAexam\3월24일 디렉터리
#
# 2021-03-29  오후 11:09    <DIR>          .
# 2021-03-29  오후 11:09    <DIR>          ..
# 2021-03-25  오전 11:17    <DIR>          .ipynb_checkpoints
# 2021-03-24  오후 01:16            54,401 exam0.ipynb
# 2021-03-29  오후 11:09            28,309 exam1.ipynb
# 2021-03-23  오후 04:27           248,523 mementopython3-english.pdf
# 2021-03-23  오후 04:27            64,181 Python3_reference_cheat_sheet_back.png
# 2021-03-23  오후 04:27            70,862 Python3_reference_cheat_sheet_front.png
# 2021-03-24  오후 12:53         2,282,152 Python빅데이터분석테스트환경구축.docx
# 2021-03-24  오후 12:53         1,549,736 Python빅데이터분석테스트환경구축.pdf
# 2021-03-24  오후 07:40    <DIR>          video
# 2021-03-24  오후 12:07           796,943 파이썬데이터수집.pdf
# 2021-03-24  오후 12:07           725,772 파이썬데이터수집.pptx
#                9개 파일           5,820,879 바이트
#                4개 디렉터리  80,541,736,960 바이트 남음

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
res_header = res.getheaders()
print("[ header 정보 ]----------")
for s in res_header :
    print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# [ header 정보 ]----------
# ('Server', 'NWS')
# ('Date', 'Mon, 29 Mar 2021 14:33:11 GMT')
# ('Content-Type', 'text/html; charset=UTF-8')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Set-Cookie', 'PM_CK_loc=ed2e13eef397c34582d1b2feb1381a18a918bb81e5de690ba5b27eedd0ed6630; Expires=Tue, 30 Mar 2021 14:33:11 GMT; Path=/; HttpOnly')
# ('Cache-Control', 'no-cache, no-store, must-revalidate')
# ('Pragma', 'no-cache')
# ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"')
# ('X-Frame-Options', 'DENY')
# ('X-XSS-Protection', '1; mode=block')
# ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains')
# ('Referrer-Policy', 'unsafe-url')

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res) #객체 정보 확인
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read())
print(res.read().decode('utf-8'))
# Out:
# <http.client.HTTPResponse object at 0x0000024401BF3AF0>
# [ header 정보 ]----------
# ('Date', 'Mon, 29 Mar 2021 14:35:12 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info())) 
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding) #500 = 500byte만 읽겠다
print(text)
print("===========================================================")

url = 'https://www.daum.net/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.aladin.co.kr/home/welcome.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.daum.net/  페이지의 인코딩 정보 : utf-8
# <!DOCTYPE html>
# <html lang="ko" class="">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta property="og:url" content="https://www.daum.net/">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Daum">
# <meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">
# <meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">
# <meta name="msapplication-task" content="name=Daum;action-
# ===========================================================
# https://www.aladin.co.kr/home/welcome.aspx  페이지의 인코딩 정보 : utf-8
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" >
# <html>
#   <head>
#       <title id="Title">알라딘</title>
#       <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
# 	  <meta content="Microsoft Visual Studio .NET 7.1" name="GENERATOR">
# 	  <meta content="C#" name="CODE_LANGUAGE">
# 	  <meta content="JavaScript" name="vs_defaultClientScript">
# 	  <meta content="http://schemas.microsoft.com/intellisense/ie5" name="vs_targetSchema">
#       <meta http-equiv="
# ===========================================================

# %%
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))

# %%
# 3월 25일

import requests
# request란 모듈을 import해주는 것

# 요청방식 = get
r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
# html 문서에 대한 헤더, 바디 정보를 가져와로 해석됨. request가 리턴하는 것이 response 객체.
# 텍스트 속성 값을 읽어보면 바디 내용을 가져올 수 있다.
r.encoding = 'utf-8'
# 특히 한글일 때, 텍스트 랎을 읽기 전에 encoding = utf-8을 설정해놓고 읽으라는 의미
print(type(r))
# request 함수가 리턴하는 객체가 어떤 것인지 확인시켜주는 type 함수
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')

# 요청방식 = request
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
# head 방식이 올 땐, 바디가 없다.
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
    # 
print('----------------------------------------------------------')

# 요청방식 = post
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))

# %%
import requests
from PIL import Image
from io import BytesIO

# 이미지 파일 저장

# html 형식이 아닌 binary png 형식 파일 불러오기
r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
# binary일 때 content 사용
i = Image.open(BytesIO(r.content))

print(type(i))
i.save("c:/Temp/test.jpg")
# jpg면 jpg 파일 객체, png면 png 파일 객체에 맞게 만들어 save함수를 이용해 해당 디렉토리에 저장
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
#여러 행에 걸쳐 문자열 데이터를 만들고 싶을 땐 인용부호 3개 이용
html_doc = """ 
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser') #BeautifulSoup 객체 생성
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify()) #prettify 메서드 활용: 들여쓰기가 적용됨
print(bs)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>
#
#
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Test BeautifulSoup</title>
# </head>
# <body>
# <p align="center">P태그의 컨텐트</p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
# </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser') #내부적으로 dom객체가 만들어지고, bfs 객체에 매달리는 모습이 될 것.
print(type(bs.title), ':', bs.title) #html, head, body 태그는 생략 가능 
print(type(bs.title.name), ':', bs.title.name) #태그 이름
print(type(bs.title.string), ':', bs.title.string) #컨텐츠
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align']) #align 속성의 값이 출력 = "center"
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs) #img 태그의 모든 속성을 딕셔너리 형태로 출력
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[ string 속성 ]") #문자열 형식의 tag만 꺼내주는 역할 - 자손 태그는 꺼내지 않음
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[ text 속성 ]") #sub(자손) 태그의 문자열 형식을 모두 출력
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[ contents 속성 ]") #contents는 리스트로 리턴
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
# Out:
# [ string 속성 ]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [ text 속성 ]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [ contents 속성 ]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags) #태그 객체를 하나씩 꺼냄. p태그가 4개니까 4개의 result set을 돌리는 결과가 되기 때문.
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]") #앞뒤 공백 삭제
print("["+pdom.string.strip()+"]") #앞뒤 공백 삭제
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text #인코딩 처리가 따로 없음, 그렇다면 페이지가 utf-8이 아니라는 의미, 오히려 설정하면 한글 깨지는 현상 발생
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie') #태그 객체 생성
points = soup.select('td.title > div > em')
reviews = soup.select('td.title') #title 클래스 속성을 갖고 있는 td 태그를 찾아라
movie_title = [] #비어있는 리스트 객체들을 생성
movie_point = []
movie_review = [] 

for dom in titles: #반복문을 이용해서 텍스트 처리 후 append해서 리스트 객체에 넣어줌
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] # sub 태그로 모든 자식들을 리스트로 리턴
    #content=re.sub("신고", '', content) #re 모듈에서 제공하는 sub 함수 = 대체하는 것
    content=re.sub("[\n\t]", '', content) #개행을 null 문자로 대체
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 자산어보
# 평점 : 10
# 리뷰글 : 보는내내  학업열의를 느끼지 못하는 청소년들이 꼭 봤으면 좋겠단 생각이들더라   흑백영상이라도 삶의 열정은 눈부시게 찬란했다  이번 영화로 정약전 정약용 헷갈릴일이 없어요 역사공부 다시 했네요
# -----------------------------------------
# 영화 제목 : 쉬핑 뉴스
# 평점 : 6
# 리뷰글 : 평점은 본인이 느낀대로만 남기면된다. 남의 평점에 왈가왈부하는것은 어리석은 오지랖이다.
# -----------------------------------------
# 영화 제목 : 자산어보
# 평점 : 10
# 리뷰글 : 아!!!  잔잔하고 수묵화 보는 느낌. 배우들 연기가  잔잔함을 더 하네요. 영화보면서 힐링하고 왔습니다
# -----------------------------------------
# 영화 제목 : 극장판 귀멸의 칼날: 무한열차편
# 평점 : 10
# 리뷰글 : 마지막 전투씬이 진짜 레전드 꼭 봐요
# -----------------------------------------
# 영화 제목 : 자산어보
# 평점 : 10
# 리뷰글 : 오랜만에 정말 좋은 영화였다. 많은 사람들이 같은 감동을 느꼈으면 좋겠다. 여운이 남는 멋진 영화였다.
# -----------------------------------------
# 영화 제목 : 더 게스트
# 평점 : 1
# 리뷰글 : 웬만한 공포영화 다 봐서 안본영화 찾다가 보게 되었고, 웬만한 공포영화 다 재미있게 보는 편임 ㅋㅋ 근데 ㅋㅋ 전개가 개 스렉이고 암걸리고 ㅋㅋ 짜증내면서 봤음 ㅋㅋ 평점남기는거 잘 안하는데 너무 빡쳐서 평점 남기러옴 ㅋㅋ 말도 안되는 억지 전개 억지 결말 ㅡㅡ개빡처ㅔ
# -----------------------------------------
# 영화 제목 : 빅쇼트
# 평점 : 9
# 리뷰글 : 날카로운 분석. 다른 스토리들이 하나가 되어가는 하모니. 그리고 부정하고 싶은 현실.
# -----------------------------------------
# 영화 제목 : 생일
# 평점 : 10
# 리뷰글 : 러닝타임중 절반을 펑펑 울었던것 같습니다..
# -----------------------------------------
# 영화 제목 : 퓨리
# 평점 : 7
# 리뷰글 : 라이언일병구하기 보세요~
# -----------------------------------------
# 영화 제목 : 굿바이 싱글
# 평점 : 10
# 리뷰글 : 눈물.웃음 좋다. 재밌다
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n)) #페이지 변화에 따라 바뀌는 내용을 나타내기 위해 / 파이썬에선 모두 string이어야 하기 때문에 str(n)을 써주어야 함
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        #content=re.sub("신고", '', content)
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 1,공작,연기자들의 연기가 아까운 영화....김대중을 무슨 정의의사도인것마냥 표현한게 그저 웃김
# 8,내가 사랑했던 모든 남자들에게,자꾸 싸우는데 계속 화해하는 모습이 인상적임
# 10,자산어보,보는내내  학업열의를 느끼지 못하는 청소년들이 꼭 봤으면 좋겠단 생각이들더라   흑백영상이라도 삶의 열정은 눈부시게 찬란했다  이번 영화로 정약전 정약용 헷갈릴일이 없어요 역사공부 다시 했네요
# 6,쉬핑 뉴스,평점은 본인이 느낀대로만 남기면된다. 남의 평점에 왈가왈부하는것은 어리석은 오지랖이다.
# 10,자산어보,아!!!  잔잔하고 수묵화 보는 느낌. 배우들 연기가  잔잔함을 더 하네요. 영화보면서 힐링하고 왔습니다
# 10,극장판 귀멸의 칼날: 무한열차편,마지막 전투씬이 진짜 레전드 꼭 봐요
# 10,자산어보,오랜만에 정말 좋은 영화였다. 많은 사람들이 같은 감동을 느꼈으면 좋겠다. 여운이 남는 멋진 영화였다.
# 1,더 게스트,웬만한 공포영화 다 봐서 안본영화 찾다가 보게 되었고, 웬만한 공포영화 다 재미있게 보는 편임 ㅋㅋ 근데 ㅋㅋ 전개가 개 스렉이고 암걸리고 ㅋㅋ 짜증내면서 봤음 ㅋㅋ 평점남기는거 잘 안하는데 너무 빡쳐서 평점 남기러옴 ㅋㅋ 말도 안되는 억지 전개 억지 결말 ㅡㅡ개빡처ㅔ
# 9,빅쇼트,날카로운 분석. 다른 스토리들이 하나가 되어가는 하모니. 그리고 부정하고 싶은 현실.
# 10,생일,러닝타임중 절반을 펑펑 울었던것 같습니다..
# -----------------------------------------------------
# 7,퓨리,라이언일병구하기 보세요~
# 10,굿바이 싱글,눈물.웃음 좋다. 재밌다
# 1,아수라도,반전도 없고 감동도 없고아 .. 시간이 아깝ㅠ
# 10,자산어보,리뷰 잘 안남기는데 이렇게 남깁니다진짜 명작입니다... 꼭 보세요
# 4,끌로드 부인,범죄자의 지리멸렬한 똥폼잡기
# -----------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8" => yes24 사이트도 utf-8이 아니라는 의미
bs = BeautifulSoup(r.text, 'html.parser')
titleList = bs.select('p.goods_name.goods_icon > a > strong')
linklList = bs.select('p.goods_name.goods_icon > a')

for titleDom in titleList:
    title.append(titleDom.string) #
for linkDom in linklList:
    link.append(linkDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)

#파일저장
with open('booklink.csv', "wt", encoding="utf-8") as f: #텍스트 기반의 쓰기 모드로 열겠다
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', '두근두근 파이썬', '파이썬 for Beginner', '파이썬을 이용한 비트코인 자동매매', '밑바닥부터 시작하는 딥러닝 ', '파이썬 증권 데이터 분석 ', '파이썬 알고리즘 인터뷰', '핸즈온 머신러닝', '파이썬 머신러닝 완벽 가이드', '실전 시계열 분석', 'Do it! 파이썬 생활 프로그래밍', 'Do it! 점프 투 파이썬 + Do it! 파이썬 생활 프로그래밍', '혼자 공부하는 첫 프로그래밍 with 파이썬 ', '시간순삭 파이썬', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', 'Do it! 점프 투 파이썬 + Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편 + Do it! 파이썬 생활 프로그래밍', '밑바닥부터 시작하는 딥러닝 2']
# -- 도서 링크 URL --
# ['/Product/Goods/74419916?OzSrank=1', '/Product/Goods/74269975?OzSrank=2', '/Product/Goods/96024871?OzSrank=3', '/Product/Goods/91433923?OzSrank=4', '/Product/Goods/35279965?OzSrank=5', '/Product/Goods/83849188?OzSrank=6', '/Product/Goods/98135876?OzSrank=7', '/Product/Goods/34970929?OzSrank=8', '/Product/Goods/90578506?OzSrank=9', '/Product/Goods/91084402?OzSrank=10', '/Product/Goods/89959711?OzSrank=11', '/Product/Goods/87044746?OzSrank=12', '/Product/Goods/98576347?OzSrank=13', '/Product/Goods/91437485?OzSrank=14', '/Product/Goods/91446225?OzSrank=15', '/Product/Goods/90617738?OzSrank=16', '/Product/Goods/92087970?OzSrank=17', '/Product/Goods/91219874?OzSrank=18', '/Product/Goods/91446242?OzSrank=19', '/Product/Goods/72173703?OzSrank=20']

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml"
req.urlretrieve(url, savename)

xml = open(savename, "r", encoding="utf-8").read()
soup = BeautifulSoup(xml, 'html.parser')

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)]

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()):
        f.write(str(loc)+'\n')
        for name in info[loc]:
            f.write('\t'+str(name)+'\n')
# Out:
# {'서울': ['6~15', '6~15', '4~15', '4~15', '5~17', '5~17', '8~20', '8~20', '10~17', '10~17', '9~16', '8~16', '7~17'], '인천': ['6~13', '6~13', '5~13', '5~13', '6~15', '6~15', '8~17', '8~17', '9~15', '9~15', '9~14', '8~14', '8~14'], '수원': ['4~16', '4~16', '3~16', '3~16', '4~18', '4~18', '6~20', '6~20', '8~17', '8~17', '8~17', '5~16', '6~17'], '파주': ['2~16', '2~16', '0~16', '0~16', '2~17', '2~17', '4~20', '4~20', '7~18', '7~18', '7~17', '4~17', '3~17'], '이천': ['3~17', '3~17', '1~17', '1~17', '3~18', '3~18', '4~21', '4~21', '7~18', '7~18', '8~17', '5~17', '4~18'], '평택': ['4~16', '4~16', '2~16', '2~16', '4~18', '4~18', '5~21', '5~21', '8~18', '8~18', '9~16', '5~17', '5~18'], '춘천': ['3~16', '3~16', '1~16', '1~16', '2~18', '2~18', '4~20', '4~20', '7~18', '7~18', '8~16', '4~16', '3~17'], '원주': ['4~16', '4~16', '3~16', '3~16', '3~18', '3~18', '6~21', '6~21', '9~19', '9~19', '9~17', '5~16', '5~17'], '강릉': ['7~14', '7~14', '4~13', '4~13', '5~17', '5~17', '9~19', '9~19', '10~17', '10~17', '11~16', '7~16', '8~18'], '대전': ['5~17', '5~17', '3~16', '3~16', '4~19', '4~19', '6~21', '6~21', '9~18', '9~18', '11~17', '6~19', '6~19'], '세종': ['4~16', '4~16', '2~16', '2~16', '3~18', '3~18', '5~20', '5~20', '8~18', '8~18', '10~16', '5~18', '5~18'], '홍성': ['3~15', '3~15', '1~15', '1~15', '2~17', '2~17', '4~20', '4~20', '7~16', '7~16', '9~15', '4~17', '4~17'], '청주': ['6~16', '6~16', '4~16', '4~16', '5~18', '5~18', '7~21', '7~21', '10~19', '10~19', '11~17', '6~17', '6~19'], '충주': ['3~15', '3~15', '1~15', '1~15', '2~18', '2~18', '4~21', '4~21', '7~18', '7~18', '9~17', '4~16', '4~18'], '영동': ['3~17', '3~17', '0~16', '0~16', '1~18', '1~18', '3~21', '3~21', '6~17', '6~17', '9~16', '2~17', '2~18'], '광주': ['7~17', '7~17', '4~17', '4~17', '6~19', '6~19', '8~21', '8~21', '11~19', '11~19', '12~17', '7~18', '7~18'], '목포': ['8~14', '8~14', '6~14', '6~14', '7~16', '7~16', '8~18', '8~18', '11~17', '11~17', '10~15', '7~15', '7~15'], '여